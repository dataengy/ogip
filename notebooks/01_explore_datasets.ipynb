# %% [markdown]
# # OGIP — exploring the ML-ready datasets
#
# The pipeline (`make run`) produces Parquet under `.run/data/outputs/`. This notebook is the
# primary DS-facing interface: load the datasets and eyeball the features.
#
# - `games.parquet` — one row per resolved game (core dimension)
# - `market_features.parquet` — FS-layer features (popularity, critic score, …)

# %%
from pathlib import Path

import duckdb
import pandas as pd  # noqa: F401

OUT = next(p for p in (Path("../.run/data/outputs"), Path(".run/data/outputs")) if p.exists())
games = duckdb.sql(f"select * from read_parquet('{OUT}/games.parquet')").df()
games
# Out:
#                             game_sk  game_id                     title  \
# 0  fd9dcf1d146272bb05c490d790b6da52     3498        Grand Theft Auto V
# 1  e94fe9ac8dc10dd8b9a239e6abee2848     3328  The Witcher 3: Wild Hunt
# 2  86dba86754c0ad93997a11fa947d97b2     4200                  Portal 2
# 3  48237d9f2dea8c74c2a72126cf63d933     5286        Tomb Raider (2013)
# 4  a3d2924150c8fc0c437925e9bc080941    13536                    Portal
#
#                       slug released_date  release_year  rating  ratings_count  \
# 0       grand-theft-auto-v    2013-09-17          2013    4.47           6942
# 1  the-witcher-3-wild-hunt    2015-05-18          2015    4.66           7085
# 2                 portal-2    2011-04-18          2011    4.61           5701
# 3              tomb-raider    2013-03-05          2013    4.05           4009
# 4                   portal    2007-10-09          2007    4.51           5041
#
#    metacritic  playtime_hours  added_count
# 0          92              74        21301
# 1          92              46        20911
# 2          95              11        18516
# 3          86              10        16436
# 4          90               5        15668

# %%
features = duckdb.sql(
    f"""select title, release_year, rating, metacritic, popularity_score, critic_score
        from read_parquet('{OUT}/market_features.parquet')
        order by popularity_score desc"""
).df()
features
# Out:
#                       title  release_year  rating  metacritic  \
# 0  The Witcher 3: Wild Hunt          2015    4.66          92
# 1                  Portal 2          2011    4.61          95
# 2        Grand Theft Auto V          2013    4.47          92
# 3                    Portal          2007    4.51          90
# 4        Tomb Raider (2013)          2013    4.05          86
#
#    popularity_score  critic_score
# 0         41.314983          0.92
# 1         39.869918          0.95
# 2         39.539337          0.92
# 3         38.450267          0.90
# 4         33.601013          0.86
